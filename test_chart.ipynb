# %%
import pandas
import matplotlib.pyplot as plt

data = pandas.read_csv("cars.csv")

# %%
data.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0       130.0
# 1          Buick Skylark 320  15.0          8         350.0       165.0
# 2         Plymouth Satellite  18.0          8         318.0       150.0
# 3              AMC Rebel SST  16.0          8         304.0       150.0
# 4                Ford Torino  17.0          8         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 0  3504.0          12.0     70     US
# 1  3693.0          11.5     70     US
# 2  3436.0          11.0     70     US
# 3  3433.0          12.0     70     US
# 4  3449.0          10.5     70     US

# %%
data.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')

# %%
data.hist('Weight')
# Out:
# array([[<AxesSubplot:title={'center':'Weight'}>]], dtype=object)

# %%
data['Weight'].mean()
# Out:
# 2979.4137931034484

# %%
data[['Car', 'Weight']]
# Out:
#                            Car  Weight
# 0    Chevrolet Chevelle Malibu  3504.0
# 1            Buick Skylark 320  3693.0
# 2           Plymouth Satellite  3436.0
# 3                AMC Rebel SST  3433.0
# 4                  Ford Torino  3449.0
# ..                         ...     ...
# 401            Ford Mustang GL  2790.0
# 402          Volkswagen Pickup  2130.0
# 403              Dodge Rampage  2295.0
# 404                Ford Ranger  2625.0
# 405                 Chevy S-10  2720.0
#
# [406 rows x 2 columns]

# %%
data.iloc[1]
# Out:
# Car             Buick Skylark 320
# MPG                          15.0
# Cylinders                       8
# Displacement                350.0
# Horsepower                  165.0
# Weight                     3693.0
# Acceleration                 11.5
# Model                          70
# Origin                         US
# Name: 1, dtype: object

# %%
toyota_cars = data[data['Car'].str.contains('Toyota', na=False)]
toyota_cars.count()
# Out:
# Car             26
# MPG             26
# Cylinders       26
# Displacement    26
# Horsepower      26
# Weight          26
# Acceleration    26
# Model           26
# Origin          26
# dtype: int64

# %%
weight_average = data.groupby(['Weight']).mean()

plt.figure(figsize=(23, 3))
plt.plot(weight_average.index, weight_average['Model'])

# %%
n = data.groupby(['Origin']).count()
n.index

plt.plot(n.index, n)
